# %%
#SERVER
import random

class Server:
    def __init__(self, server_id, ip_address, total_cpu, total_memory, total_bandwidth, network_distance, hosted_services=None):
        self.server_id = server_id
        self.network_distance = network_distance
        self.ip_address = ip_address
        self.total_cpu = total_cpu
        self.total_memory = total_memory
        self.total_bandwidth = total_bandwidth
        self.available_cpu = total_cpu  # Initially, all resources are available
        self.available_memory = total_memory
        self.available_bandwidth = total_bandwidth
        self.hosted_services = hosted_services if hosted_services is not None else []

    def calculate_agg_resources(self): # not planning to use it now
        """Calculate the average resource utilization as an aggregate metric."""
        return (self.available_cpu + self.available_memory + self.available_bandwidth) / 3

    
    def add_service_function(self, service_function):
        self.hosted_services.append(service_function)

    def remove_service_function(self, service_function):
        self.hosted_services.remove(service_function)

    def list_service_functions(self):
        return self.hosted_services
    
    def calculate_latency_priority(self, microservice):
        """Simulate latency based on network distance and server load, in real life we would have the microservice ping the server."""
        base_latency = self.network_distance * 0.5  # Simplified calculation
        return base_latency
    
    def meets_requirements(self, cpu_requirement, memory_requirement, bandwidth_requirement):
        """Check if the server has enough resources to host the microservice."""
        return (self.available_cpu >= cpu_requirement and
                self.available_memory >= memory_requirement and
                self.available_bandwidth >= bandwidth_requirement)
    def deploy_microservice(self, microservice):
        #Deploy service and subtract required resources
        if not self.meets_requirements(microservice.cpu_requirement, microservice.memory_requirement, microservice.bandwidth_requirement):
            return False  # Deployment fails due to insufficient resources
        
        self.available_cpu -= microservice.cpu_requirement
        self.available_memory -= microservice.memory_requirement
        self.available_bandwidth -= microservice.bandwidth_requirement
        self.hosted_services.append(microservice.service_id)
        microservice.server=self
        return True

    def remove_microservice(self, microservice):
        #remove a service and re-add used resources to server
        if microservice.service_id in self.hosted_services:
            self.available_cpu += microservice.cpu_requirement
            self.available_memory += microservice.memory_requirement
            self.available_bandwidth += microservice.bandwidth_requirement
            self.hosted_services.remove(microservice.service_id)
            microservice.server= None

    def __str__(self):
        return (f"Server(ID={self.server_id}, IP={self.ip_address}, "
                f"CPU={self.available_cpu}, Memory={self.available_memory}, "
                f"Bandwidth={self.available_bandwidth}, Distance={self.network_distance}, "
                f"Hosted_Services={len(self.hosted_services)})")

       


#MICROSERVICE  
class Microservice:
    def __init__(self, service_id, name, cpu_requirement, memory_requirement, bandwidth_requirement, latency_threshold, server=None):
        self.service_id = service_id
        self.name = name
        self.cpu_requirement = cpu_requirement
        self.memory_requirement = memory_requirement
        self.bandwidth_requirement = bandwidth_requirement
        self.latency_threshold = latency_threshold
        self.server = server  # HOST SERVER

    def __str__(self):
        server_id = self.server.server_id if self.server else "Not deployed"
        return (f"Microservice(name={self.name}, CPU={self.cpu_requirement}, "
                f"Memory={self.memory_requirement}, Bandwidth={self.bandwidth_requirement}, "
                f"Latency Threshold={self.latency_threshold}ms, Server={server_id})")




# GRAPH
import numpy as np
import heapq
import networkx as nx
import matplotlib.pyplot as plt
class NetworkGraph:
    def __init__(self):
        self.nodes = {}  # Stores server objects with server_id as key
        self.edges = {}  # Stores connections and their properties

    def add_server(self, server):
        """Add a server"""
        self.nodes[server.server_id] = server
        self.edges[server.server_id] = []

    def connect_servers(self, server_id1, server_id2, latency, bandwidth):
        """Connect two servers with specified latency and bandwidth."""
        if server_id1 not in self.nodes or server_id2 not in self.nodes:
            raise ValueError("One or both of the servers not found in the graph.")
        
        connection_info = {'latency': latency, 'bandwidth': bandwidth}
        self.edges[server_id1].append((server_id2, connection_info))
        self.edges[server_id2].append((server_id1, connection_info))

    def get_server_connections(self, server_id):
        """Retrieve a server's connections and their properties."""
        return self.edges.get(server_id, [])

    def __str__(self):
        """Provide a string overload of the graph for debugging purposes."""
        description = "Network Graph:\n"
        for server_id in self.nodes:
            description += f"Server {server_id} connections: {self.edges[server_id]}\n"
        return description
    
    def find_shortest_path(self, start_server_id, end_server_id):
        """Find the shortest path from start to end server based on latency using Dijkstra"""
        distances = {server_id: float('inf') for server_id in self.nodes}
        distances[start_server_id] = 0
        priority_queue = [(0, start_server_id)]
        predecessor = {server_id: None for server_id in self.nodes}

        while priority_queue:
            current_distance, current_server_id = heapq.heappop(priority_queue)
            if current_server_id == end_server_id:
                break

            for neighbor, connection_info in self.get_server_connections(current_server_id):
                distance = current_distance + connection_info['latency']
                if distance < distances[neighbor]:
                    distances[neighbor] = distance
                    predecessor[neighbor] = current_server_id
                    heapq.heappush(priority_queue, (distance, neighbor))

        # Reconstructing path
        path = []
        current = end_server_id
        while current is not None:
            path.append(current)
            current = predecessor[current]
        path.reverse()

        return path if path[0] == start_server_id else None
    
    def average_network_latency(self):
        """Calculate the average latency across all connections in the graph."""
        total_latency, count = 0, 0
        for server_id in self.edges:
            for connection in self.edges[server_id]:
                _, connection_info = connection
                total_latency += connection_info['latency']
                count += 1
        return total_latency / count if count > 0 else 0
    

    def update_connection(self, server_id1, server_id2, latency=None, bandwidth=None):
        """Update the properties of a connection between two servers."""
        if server_id1 in self.edges and server_id2 in self.edges:
            for i, (target_id, info) in enumerate(self.edges[server_id1]):
                if target_id == server_id2:
                    if latency is not None:
                        self.edges[server_id1][i][1]['latency'] = latency
                    if bandwidth is not None:
                        self.edges[server_id1][i][1]['bandwidth'] = bandwidth
                    break
            # Bidirectional repeat for the reverse connection
            for i, (target_id, info) in enumerate(self.edges[server_id2]):
                if target_id == server_id1:
                    if latency is not None:
                        self.edges[server_id2][i][1]['latency'] = latency
                    if bandwidth is not None:
                        self.edges[server_id2][i][1]['bandwidth'] = bandwidth
                    break
        else:
            raise ValueError("One or both of the servers not found in the graph.")
        

    def calculate_load_imbalance(self):
        """
        Calculate the imbalance in server load across the network.
        
        Returns a dictionary with the standard deviation of CPU, memory, and bandwidth utilizations,
            indicating the level of imbalance. Lower values indicate a more balanced load.
        """
        cpu_utilizations = []
        memory_utilizations = []
        bandwidth_utilizations = []
        
        for server_id, server in self.nodes.items():
            cpu_util = (server.total_cpu - server.available_cpu) / server.total_cpu if server.total_cpu else 0
            memory_util = (server.total_memory - server.available_memory) / server.total_memory if server.total_memory else 0
            bandwidth_util = (server.total_bandwidth - server.available_bandwidth) / server.total_bandwidth if server.total_bandwidth else 0
            
            cpu_utilizations.append(cpu_util)
            memory_utilizations.append(memory_util)
            bandwidth_utilizations.append(bandwidth_util)
        
        # Calculate standard deviation for each resource utilization
        cpu_std = np.std(cpu_utilizations) if cpu_utilizations else 0
        memory_std = np.std(memory_utilizations) if memory_utilizations else 0
        bandwidth_std = np.std(bandwidth_utilizations) if bandwidth_utilizations else 0
        
        return {
            'cpu_std': cpu_std,
            'memory_std': memory_std,
            'bandwidth_std': bandwidth_std
        }
    def get_average_latency_to_other_servers(self, server_id):
        """Calculate the average latency from a specified server to all other servers."""
        if server_id not in self.edges:
            raise ValueError(f"Server {server_id} not found in the graph.")
        
        total_latency = 0
        connections = 0
        for connection in self.edges[server_id]:
            neighbor_id, connection_info = connection
            total_latency += connection_info['latency']
            connections += 1
        
        # We don't divide by zero if a server has no connections
        if connections == 0:
            return float('inf')  
        
        return total_latency / connections
    
    def visualize(self):
        """Visualize the network graph."""
        G = nx.Graph()
        for server_id in self.nodes:
            G.add_node(server_id)
        for server_id, connections in self.edges.items():
            for target_id, info in connections:
                G.add_edge(server_id, target_id, weight=info['latency'])
        
        pos = nx.spring_layout(G)  # positions for all nodes
        nx.draw_networkx_nodes(G, pos, node_size=700)
        nx.draw_networkx_edges(G, pos, width=2)
        nx.draw_networkx_labels(G, pos, font_size=10, font_family="sans-serif")
        
        edge_labels = dict([((u, v,), f"{d['weight']}ms")
                            for u, v, d in G.edges(data=True)])
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
        
        plt.axis('off')
        plt.show()




#ENVIRONMENT

class MicroserviceDeploymentEnv:
    def __init__(self, graph, microservices):
        self.graph = graph  
        self.microservices = microservices
        self.current_microservice = None
        self.state_size = None
        self.action_size = len(graph.nodes)  # Dynamically determined by the number of servers in the graph

    def reset(self):
        # Optionally, reset the state of each server (make all resources available again)
        # This step is based on your simulation needs and how you've implemented the Server class
        for server_id, server in self.graph.nodes.items():
            server.available_cpu = server.total_cpu
            server.available_memory = server.total_memory
            server.available_bandwidth = server.total_bandwidth
            # Assuming hosted_services should be cleared too
            server.hosted_services.clear()

        # Select a new microservice to deploy; you can use a random or sequential selection method
        self.current_microservice = random.choice(self.microservices)  # Example: Randomly choose a new microservice

        # Return the initial state based on the new current microservice
        return self.get_state(self.current_microservice)  

    @staticmethod        
    def  normalize(value, min_value, max_value):
        """Normalize a value to 0-1 range for optimal dqn input"""

        return (value - min_value) / (max_value - min_value) if max_value > min_value else 0
    

    def get_state(self, microservice):

        min_vals = [0, 0, 0, 0]  # Example min values for CPU, memory, bandwidth, and latency
        max_vals = [
            max(m.cpu_requirement for m in self.microservices),
            max(m.memory_requirement for m in self.microservices),
            max(m.bandwidth_requirement for m in self.microservices),
            max(m.latency_threshold for m in self.microservices)
        ]  # Max values based on the microservices in your environment
        state = []
        # Add server states with additional load ratio information
        total_cpu_utilization = 0
        total_memory_utilization = 0
        total_bandwidth_utilization = 0
        num_servers = len(self.graph.nodes)
        
        for server_id, server in self.graph.nodes.items():
            normalized_cpu = self.normalize(server.available_cpu, 0, server.total_cpu)
            normalized_memory = self.normalize(server.available_memory, 0, server.total_memory)
            normalized_bandwidth = self.normalize(server.available_bandwidth, 0, server.total_bandwidth)
            cpu_load_ratio = (server.total_cpu - server.available_cpu) / server.total_cpu
            memory_load_ratio = (server.total_memory - server.available_memory) / server.total_memory
            bandwidth_load_ratio = (server.total_bandwidth - server.available_bandwidth) / server.total_bandwidth

            total_cpu_utilization += cpu_load_ratio
            total_memory_utilization += memory_load_ratio
            total_bandwidth_utilization += bandwidth_load_ratio
            
            server_state = [
                normalized_cpu,
                normalized_memory,
                normalized_bandwidth,
                self.graph.get_average_latency_to_other_servers(server_id),
                cpu_load_ratio,
                memory_load_ratio,
                bandwidth_load_ratio
            ]
            state.extend(server_state)

        # Include overall network utilization
        state.extend([
            total_cpu_utilization / num_servers,
            total_memory_utilization / num_servers,
            total_bandwidth_utilization / num_servers
           

        ])
        # Add microservice requirements
        microservice_state = [
            microservice.cpu_requirement,
            microservice.memory_requirement,
            microservice.bandwidth_requirement,
            microservice.latency_threshold
        ]
        # Normalize and add to state
        state.extend([self.normalize(val, min_val, max_val) for val, min_val, max_val in zip(microservice_state, min_vals, max_vals)])
        # Add global network metric
        state.append(self.graph.average_network_latency())
        return state


    def execute_action(self, action):
        # Action is the index corresponding to a server in the graph.nodes dictionary
        server_ids = list(self.graph.nodes.keys())
        try:
            selected_server_id = server_ids[action] 
            selected_server = self.graph.nodes[selected_server_id]
            #deploy the microservice to the selected server
            if self.current_microservice and selected_server.meets_requirements(
                self.current_microservice.cpu_requirement,
                self.current_microservice.memory_requirement,
                self.current_microservice.bandwidth_requirement
            ):
                success = selected_server.deploy_microservice(self.current_microservice)
                if success:
                    ## NEW MODDDDDDDDDDDDDDDDDDDDDD

                
                    reward = self.calculate_reward(action, success)  # Return True if deployment is successful
                    return reward, success
                
        except IndexError:
            # Handle invalid action (e.g., action index out of range)
            pass

        return self.calculate_reward(action, success=False), False   # Return False if deployment fails or is invalid
    
    def calculate_reward(self, action, success):
        """
        Calculate the reward for deploying a microservice based on the action's success and system state.
        
        Parameters:
            action (int): The destination server of the action attempted
            success: Whether the microservice deployment was successful.
        
        Returns the calculated reward for the action.
             
        """
        if not self.current_microservice:
            # No microservice is selected for deployment...system error.
            return -10  # Penalize heavily
        
        server_ids = list(self.graph.nodes.keys())
        try:
            selected_server_id = server_ids[action]
            selected_server = self.graph.nodes[selected_server_id]
        except IndexError:
            # Action led to an invalid server selection
            return -5
        
        if not success:
            # Deployment failed. Penalize to a degree but less than system errors.
            print(" \n FAILED DEPLOYMENT \n")
            return -2

        # If deployment was successful, positive reward is calculated based on several factors, we can supplement it if necessary
        reward = 0
        
        # Factor 1: Resource Utilization Efficiency. Encourage efficient use of server resources without overloading.

        cpu_utilization = (selected_server.total_cpu - selected_server.available_cpu) / selected_server.total_cpu
        memory_utilization = (selected_server.total_memory - selected_server.available_memory) / selected_server.total_memory
        bandwidth_utilization = (selected_server.total_bandwidth - selected_server.available_bandwidth) / selected_server.total_bandwidth
        
        # Average utilization leads to balanced use of resources.
        avg_utilization = (cpu_utilization + memory_utilization + bandwidth_utilization) / 3
        reward += 5 * avg_utilization  
        # print(f' REWARD BEFORE LOAD IMBALANCE {reward} \n/n')
        # Factor 2: Network Performance. Penalize if the deployment significantly impacts network latency or does not meet latency requirements.

        if selected_server.calculate_latency_priority(self.current_microservice) > self.current_microservice.latency_threshold:
            # Penalize for exceeding latency threshold, scaled by how much it was exceeded.
            reward -= 5 * (selected_server.calculate_latency_priority(self.current_microservice) / self.current_microservice.latency_threshold)
            print(" PENALIZED FOR LATENCY\n ")
        
        # Factor 3: Load Balancing. Reward deployments that help balance the load across the network.
        
        
        load_imbalance = self.graph.calculate_load_imbalance()  # Assess load balance across servers.
        avg_imbalance = (load_imbalance['cpu_std'] + load_imbalance['memory_std'] + load_imbalance['bandwidth_std']) / 3

        reward -= 6.1 * avg_imbalance  # Penalize based on degree of imbalance to encourage load balancing.
        
        # OTHERS
        
        return reward



import numpy as np
import matplotlib.pyplot as plt



def plot_resource_utilization_for_all_servers(graph):
    for server_id, server in graph.nodes.items():
        utilized_cpu = server.total_cpu - server.available_cpu
        utilized_memory = server.total_memory - server.available_memory
        utilized_bandwidth = server.total_bandwidth - server.available_bandwidth

        resources = ['CPU', 'Memory', 'Bandwidth']
        total_resources = [server.total_cpu, server.total_memory, server.total_bandwidth]
        utilized_resources = [utilized_cpu, utilized_memory, utilized_bandwidth]

        fig, ax = plt.subplots()
        ax.bar(resources, total_resources, label='Total')
        ax.bar(resources, utilized_resources, label='Utilized', width=0.5)

        ax.set_ylabel('Resources')
        ax.set_title(f'Server {server_id} Resource Utilization')
        ax.legend()

        plt.show()

def plot_resource_utilization_for_all_servers_pct(graph):
    for server_id, server in graph.nodes.items():
        utilized_cpu_percent = ((server.total_cpu - server.available_cpu) / server.total_cpu) * 100 if server.total_cpu else 0
        utilized_memory_percent = ((server.total_memory - server.available_memory) / server.total_memory) * 100 if server.total_memory else 0
        utilized_bandwidth_percent = ((server.total_bandwidth - server.available_bandwidth) / server.total_bandwidth) * 100 if server.total_bandwidth else 0

        resources = ['CPU', 'Memory', 'Bandwidth']
        utilized_resources_percent = [utilized_cpu_percent, utilized_memory_percent, utilized_bandwidth_percent]

        fig, ax = plt.subplots()
        ax.bar(resources, utilized_resources_percent, color=['blue', 'orange', 'green'])

        ax.set_ylabel('Utilization (%)')
        ax.set_title(f'Server {server_id} Resource Utilization')
        ax.set_ylim(0, 100) 

       
        for i, utilization in enumerate(utilized_resources_percent):
            ax.text(i, utilization + 2, f'{utilization:.2f}%', ha='center', va='bottom')

        plt.show()

def list_servers_and_microservices(graph):
    print("\nListing all servers and deployed microservices:")
    for server_id, server in graph.nodes.items():
        deployed_services = [ms_id for ms_id in server.hosted_services]
        print(f"Server {server_id} ({server.ip_address}): Deployed Microservices -> {deployed_services}")




import torch
import torch.nn as nn
import torch.optim as optim

class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.network(x)

from collections import namedtuple, deque
import random

Experience = namedtuple('Experience', ('state', 'action', 'next_state', 'reward', 'done'))


class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = deque([],maxlen=capacity)

    def push(self, *args):
        self.memory.append(Experience(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# First, let's assume the classes for Server, Microservice, and NetworkGraph
# are already defined as per our earlier discussion.

# Sample environment setup
servers = [
    Server("s1", "10.0.0.1", 1300, 756, 1000, 10),
    Server("s2", "10.0.0.2", 2500, 1512, 2000, 20),
    Server("s3", "10.0.0.3", 1550, 1384, 1500, 15),
    Server("s4", "10.0.0.4", 1580, 1156, 1800, 5),
    Server("s5", "10.0.0.5", 1500, 1128, 500, 30),
]

microservices = [
    Microservice("m1", "Auth", 20, 64, 100, 25),
    Microservice("m2", "Data", 50, 128, 200, 15),
    Microservice("m3", "Analytics", 30, 96, 150, 20),
    Microservice("m11", "AuZBRth", 20, 64, 100, 25),
    Microservice("m22", "DaZBRta", 50, 128, 200, 15),
    Microservice("m32", "ZBRnalytics", 30, 96, 150, 20),
]

# Initializing the network graph
network_graph = NetworkGraph()
for server in servers:
    network_graph.add_server(server)

# Example connections
network_graph.connect_servers("s1", "s2", 10, 100)
network_graph.connect_servers("s1", "s3", 15, 80)
network_graph.connect_servers("s2", "s4", 20, 120)
network_graph.connect_servers("s3", "s4", 5, 150)
network_graph.connect_servers("s4", "s5", 10, 100)
network_graph.connect_servers("s3", "s5", 20, 70)

# Instantiate the environment
env = MicroserviceDeploymentEnv(network_graph, microservices)

# Calculating state and action sizes
number_of_servers = len(servers)  # N
state_size = (7 * number_of_servers) + 3 + 4 + 1
action_size = number_of_servers  # N

print(f"State Size: {state_size}, Action Size: {action_size}")

#DQN INITALIZATION

BATCH_SIZE = 256
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.04
EPS_DECAY = 200
TARGET_UPDATE = 5


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

policy_net = DQN(input_size=state_size, output_size=action_size).to(device)
target_net = DQN(input_size=state_size, output_size=action_size).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters())
memory = ReplayMemory(10000)
steps_done = 0

def select_action(state):
    global steps_done
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if random.random() > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return largest column value of each row.
            # second column on max result is index of where max element was found
            # we pick action with the larger expected reward.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(action_size)]], device=device, dtype=torch.long)

import torch
import torch.nn.functional as F
import math
from itertools import count

def optimize_model():
    if len(memory) < BATCH_SIZE:
        return  # Not enough samples in memory to sample a batch

    transitions = memory.sample(BATCH_SIZE)
    batch = Experience(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)), dtype=torch.bool)
    non_final_next_states_list = [s for s in batch.next_state if s is not None]


    if not non_final_next_states_list:
        return  # FINAL STATE

    non_final_next_states = torch.cat(non_final_next_states_list)

    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the columns of actions taken
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    next_state_values = torch.zeros(BATCH_SIZE)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()


load_arr = []
num_episodes = 2200  # Number of episodes to train on
for i_episode in range(num_episodes):
    env.reset()  # Reset the environment at the start of each episode
    total_reward = 0  # Initialize total reward for the episode

    # Iterate through each microservice within the same episode
    for microservice in env.microservices:
        env.current_microservice = microservice  # Update the current microservice in the environment
        state = torch.tensor([env.get_state(microservice)], dtype=torch.float32, device=device)

        for t in count():  # Iterate until the episode is done or a certain condition is met
            action = select_action(state)
            reward, done = env.execute_action(action.item())
            reward = torch.tensor([reward], device=device)

            total_reward += reward.item()  # Accumulate the reward

            # Observe new state
            if not done:
                next_state = torch.tensor([env.get_state(microservice)], dtype=torch.float32, device=device)
            else:
                next_state = None

            # Store the transition in memory
            memory.push(state, action, next_state, reward, torch.tensor([done], dtype=torch.bool, device=device))

            # Move to the next state
            state = next_state

            # Perform one step of the optimization (on the policy network)
            optimize_model()
            if done:
                break  # Break from the loop if done

    # Print the total reward for the current episode
    load_imbalance = env.graph.calculate_load_imbalance()  # Assess load balance across servers.
    avg_imbalance = (load_imbalance['cpu_std'] + load_imbalance['memory_std'] + load_imbalance['bandwidth_std']) / 3        
    
    load_arr.append(avg_imbalance)
    print(f'Episode {i_episode+1}, Total Reward: {total_reward}')

    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())


print('Training complete')

print(load_arr)
network_graph.visualize()
plt.figure(figsize=(10, 6))
plt.plot(load_arr, label='Load Imbalance')
plt.xlabel('Episode')
plt.ylabel('Load Imbalance')
plt.title('Load Imbalance Over Episodes')
plt.legend()
plt.show()
list_servers_and_microservices(network_graph)
plot_resource_utilization_for_all_servers_pct(network_graph)
# Out:
# State Size: 43, Action Size: 5
# Episode 1, Total Reward: 2.245935703253868
# Episode 2, Total Reward: 2.251766842467268
# Episode 3, Total Reward: 1.338582835283137
# Episode 4, Total Reward: 1.7872809518034105
# Episode 5, Total Reward: 2.8365140336012367
# Episode 6, Total Reward: 1.400794346111789
# Episode 7, Total Reward: 1.6962062612666846
# Episode 8, Total Reward: 1.2542121735388725
# Episode 9, Total Reward: 1.483863603763619
# Episode 10, Total Reward: 2.1023253733255656
# Episode 11, Total Reward: 2.315682157640312
# Episode 12, Total Reward: 0.08604451801402335
# Episode 13, Total Reward: 1.5340197299411233
# Episode 14, Total Reward: 2.0689908808781725
# Episode 15, Total Reward: 0.43602805500224845
# Episode 16, Total Reward: 1.4290685544719512
# Episode 17, Total Reward: 5.252341337674671
# Episode 18, Total Reward: 0.5427894122189301
# Episode 19, Total Reward: 1.3614145221892184
# Episode 20, Total Reward: 1.2956248990788723
# Episode 21, Total Reward: 2.101776083269067
# Episode 22, Total Reward: 3.1869100022374237
# Episode 23, Total Reward: 2.8078055081599893
# Episode 24, Total Reward: 1.8454581855924568
# Episode 25, Total Reward: 3.608930286842325
# Episode 26, Total Reward: 1.8551324551749375
# Episode 27, Total Reward: 1.3137282021911405
# Episode 28, Total Reward: 1.978892254110011
# Episode 29, Total Reward: 3.4458062205945144
# Episode 30, Total Reward: 5.252341337674671
# Episode 31, Total Reward: 3.549153165065487
# Episode 32, Total Reward: 3.614515486140286
# Episode 33, Total Reward: 4.39053428942428
# Episode 34, Total Reward: 2.1061484047385886
# Episode 35, Total Reward: 3.055683068936947
# Episode 36, Total Reward: 0.9839904244971388
# Episode 37, Total Reward: 4.5041269723132915
# Episode 38, Total Reward: 1.2814510726925061
# Episode 39, Total Reward: 2.292377542400702
# Episode 40, Total Reward: 2.5670454206921667
# Episode 41, Total Reward: 3.751584208672874
# Episode 42, Total Reward: 2.677008569783757
# Episode 43, Total Reward: 3.620424933595786
# Episode 44, Total Reward: 1.7554171000620857
# Episode 45, Total Reward: 5.252341337674671
# Episode 46, Total Reward: 3.567956378261502
# Episode 47, Total Reward: 5.252341337674671
# Episode 48, Total Reward: 3.567956378261502
# Episode 49, Total Reward: 4.420481582672803
# Episode 50, Total Reward: 2.7457287192908897
# Episode 51, Total Reward: 3.608930286842325
# Episode 52, Total Reward: 2.0610621838378194
# Episode 53, Total Reward: 3.549153165065487
# Episode 54, Total Reward: 5.252341337674671
# Episode 55, Total Reward: 3.498007248773058
# Episode 56, Total Reward: 3.614515486140286
# Episode 57, Total Reward: 5.252341337674671
# Episode 58, Total Reward: 3.620424933595786
# Episode 59, Total Reward: 4.4231178431426255
# Episode 60, Total Reward: 5.252341337674671
# Episode 61, Total Reward: 5.252341337674671
# Episode 62, Total Reward: 1.7894031162184896
# Episode 63, Total Reward: 5.252341337674671
# Episode 64, Total Reward: 5.252341337674671
# Episode 65, Total Reward: 5.252341337674671
# Episode 66, Total Reward: 2.3648540785218852
# Episode 67, Total Reward: 4.39053428942428
# Episode 68, Total Reward: 5.252341337674671
# Episode 69, Total Reward: 3.1929726097260858
# Episode 70, Total Reward: 5.252341337674671
# Episode 71, Total Reward: 2.3099060620142438
# Episode 72, Total Reward: 5.252341337674671
# Episode 73, Total Reward: 5.252341337674671
# Episode 74, Total Reward: 2.8137192301186382
# Episode 75, Total Reward: 5.252341337674671
# Episode 76, Total Reward: 5.252341337674671
# Episode 77, Total Reward: 5.252341337674671
# Episode 78, Total Reward: 5.252341337674671
# Episode 79, Total Reward: 5.252341337674671
# Episode 80, Total Reward: 5.252341337674671
# Episode 81, Total Reward: 5.252341337674671
# Episode 82, Total Reward: 4.420481582672803
# Episode 83, Total Reward: 5.252341337674671
# Episode 84, Total Reward: 4.4231178431426255
# Episode 85, Total Reward: 3.562370242439126
# Episode 86, Total Reward: 2.6427329576872447
# Episode 87, Total Reward: 2.3648540785218852
# Episode 88, Total Reward: 3.608930286842325
# Episode 89, Total Reward: 5.252341337674671
# Episode 90, Total Reward: 5.252341337674671
# Episode 91, Total Reward: 5.252341337674671
# Episode 92, Total Reward: 5.252341337674671
# Episode 93, Total Reward: 4.5041269723132915
# Episode 94, Total Reward: 2.8078055081599893
# Episode 95, Total Reward: 5.252341337674671
# Episode 96, Total Reward: 5.252341337674671
# Episode 97, Total Reward: 5.252341337674671
# Episode 98, Total Reward: 3.2008008568710107
# Episode 99, Total Reward: 5.252341337674671
# Episode 100, Total Reward: 5.252341337674671
# Episode 101, Total Reward: 5.252341337674671
# Episode 102, Total Reward: 5.252341337674671
# Episode 103, Total Reward: 5.252341337674671
# Episode 104, Total Reward: 5.252341337674671
# Episode 105, Total Reward: 5.252341337674671
# Episode 106, Total Reward: 5.252341337674671
# Episode 107, Total Reward: 5.252341337674671
# Episode 108, Total Reward: 5.252341337674671
# Episode 109, Total Reward: 3.620424933595786
# Episode 110, Total Reward: 5.252341337674671
# Episode 111, Total Reward: 3.1929726097260858
# Episode 112, Total Reward: 5.252341337674671
# Episode 113, Total Reward: 5.252341337674671
# Episode 114, Total Reward: 5.252341337674671
# Episode 115, Total Reward: 5.252341337674671
# Episode 116, Total Reward: 5.252341337674671
# Episode 117, Total Reward: 3.107430140147727
# Episode 118, Total Reward: 5.252341337674671
# Episode 119, Total Reward: 3.1929726097260858
# Episode 120, Total Reward: 5.252341337674671
# Episode 121, Total Reward: 5.252341337674671
# Episode 122, Total Reward: 3.567956378261502
# Episode 123, Total Reward: 3.614515486140286
# Episode 124, Total Reward: 5.252341337674671
# Episode 125, Total Reward: 5.252341337674671
# Episode 126, Total Reward: 5.252341337674671
# Episode 127, Total Reward: 5.252341337674671
# Episode 128, Total Reward: 5.252341337674671
# Episode 129, Total Reward: 3.1929726097260858
# Episode 130, Total Reward: 5.252341337674671
# Episode 131, Total Reward: 5.252341337674671
# Episode 132, Total Reward: 3.107430140147727
# Episode 133, Total Reward: 3.549153165065487
# Episode 134, Total Reward: 5.252341337674671
# Episode 135, Total Reward: 5.252341337674671
# Episode 136, Total Reward: 5.252341337674671
# Episode 137, Total Reward: 5.252341337674671
# Episode 138, Total Reward: 5.252341337674671
# Episode 139, Total Reward: 5.252341337674671
# Episode 140, Total Reward: 5.252341337674671
# Episode 141, Total Reward: 5.252341337674671
# Episode 142, Total Reward: 3.620424933595786
# Episode 143, Total Reward: 5.252341337674671
# Episode 144, Total Reward: 5.252341337674671
# Episode 145, Total Reward: 3.608930286842325
# Episode 146, Total Reward: 5.252341337674671
# Episode 147, Total Reward: 5.252341337674671
# Episode 148, Total Reward: 4.5041269723132915
# Episode 149, Total Reward: 5.252341337674671
# Episode 150, Total Reward: 3.8658701407267984
# Episode 151, Total Reward: 5.252341337674671
# Episode 152, Total Reward: 5.252341337674671
# Episode 153, Total Reward: 5.252341337674671
# Episode 154, Total Reward: 5.252341337674671
# Episode 155, Total Reward: 5.252341337674671
# Episode 156, Total Reward: 5.252341337674671
# Episode 157, Total Reward: 5.252341337674671
# Episode 158, Total Reward: 5.252341337674671
# Episode 159, Total Reward: 5.252341337674671
# Episode 160, Total Reward: 5.252341337674671
# Episode 161, Total Reward: 5.252341337674671
# Episode 162, Total Reward: 5.252341337674671
# Episode 163, Total Reward: 4.4231178431426255
# Episode 164, Total Reward: 5.252341337674671
# Episode 165, Total Reward: 2.8078055081599893
# Episode 166, Total Reward: 5.252341337674671
# Episode 167, Total Reward: 5.252341337674671
# Episode 168, Total Reward: 5.252341337674671
# Episode 169, Total Reward: 5.252341337674671
# Episode 170, Total Reward: 3.6056985896556197
# Episode 171, Total Reward: 5.252341337674671
# Episode 172, Total Reward: 5.252341337674671
# Episode 173, Total Reward: 5.252341337674671
# Episode 174, Total Reward: 4.4231178431426255
# Episode 175, Total Reward: 5.252341337674671
# Episode 176, Total Reward: 5.252341337674671
# Episode 177, Total Reward: 5.252341337674671
# Episode 178, Total Reward: 2.8137192301186382
# Episode 179, Total Reward: 5.252341337674671
# Episode 180, Total Reward: 3.562370242439126
# Episode 181, Total Reward: 5.252341337674671
# Episode 182, Total Reward: 5.252341337674671
# Episode 183, Total Reward: 5.252341337674671
# Episode 184, Total Reward: 5.252341337674671
# Episode 185, Total Reward: 5.252341337674671
# Episode 186, Total Reward: 5.252341337674671
# Episode 187, Total Reward: 5.252341337674671
# Episode 188, Total Reward: 3.6056985896556197
# Episode 189, Total Reward: 5.252341337674671
# Episode 190, Total Reward: 5.252341337674671
# Episode 191, Total Reward: 5.252341337674671
# Episode 192, Total Reward: 5.252341337674671
# Episode 193, Total Reward: 5.252341337674671
# Episode 194, Total Reward: 5.252341337674671
# Episode 195, Total Reward: 5.252341337674671
# Episode 196, Total Reward: 3.1929726097260858
# Episode 197, Total Reward: 2.8078055081599893
# Episode 198, Total Reward: 5.252341337674671
# Episode 199, Total Reward: 5.252341337674671
# Episode 200, Total Reward: 5.252341337674671
# Episode 201, Total Reward: 5.252341337674671
# Episode 202, Total Reward: 5.252341337674671
# Episode 203, Total Reward: 5.252341337674671
# Episode 204, Total Reward: 3.4458062205945144
# Episode 205, Total Reward: 3.8658701407267984
# Episode 206, Total Reward: 5.252341337674671
# Episode 207, Total Reward: 5.252341337674671
# Episode 208, Total Reward: 5.252341337674671
# Episode 209, Total Reward: 4.4231178431426255
# Episode 210, Total Reward: 5.252341337674671
# Episode 211, Total Reward: 5.252341337674671
# Episode 212, Total Reward: 3.4935117467201136
# Episode 213, Total Reward: 5.252341337674671
# Episode 214, Total Reward: 5.252341337674671
# Episode 215, Total Reward: 5.252341337674671
# Episode 216, Total Reward: 5.252341337674671
# Episode 217, Total Reward: 5.252341337674671
# Episode 218, Total Reward: 5.252341337674671
# Episode 219, Total Reward: 4.4231178431426255
# Episode 220, Total Reward: 5.252341337674671
# Episode 221, Total Reward: 5.252341337674671
# Episode 222, Total Reward: 5.252341337674671
# Episode 223, Total Reward: 5.252341337674671
# Episode 224, Total Reward: 5.252341337674671
# Episode 225, Total Reward: 4.420481582672803
# Episode 226, Total Reward: 5.252341337674671
# Episode 227, Total Reward: 5.252341337674671
# Episode 228, Total Reward: 5.252341337674671
# Episode 229, Total Reward: 5.252341337674671
# Episode 230, Total Reward: 4.420481582672803
# Episode 231, Total Reward: 5.252341337674671
# Episode 232, Total Reward: 5.252341337674671
# Episode 233, Total Reward: 5.252341337674671
# Episode 234, Total Reward: 5.252341337674671
# Episode 235, Total Reward: 3.2008008568710107
# Episode 236, Total Reward: 5.252341337674671
# Episode 237, Total Reward: 5.252341337674671
# Episode 238, Total Reward: 5.252341337674671
# Episode 239, Total Reward: 5.252341337674671
# Episode 240, Total Reward: 5.252341337674671
# Episode 241, Total Reward: 5.252341337674671
# Episode 242, Total Reward: 5.252341337674671
# Episode 243, Total Reward: 5.252341337674671
# Episode 244, Total Reward: 5.252341337674671
# Episode 245, Total Reward: 5.252341337674671
# Episode 246, Total Reward: 5.252341337674671
# Episode 247, Total Reward: 5.252341337674671
# Episode 248, Total Reward: 5.252341337674671
# Episode 249, Total Reward: 5.252341337674671
# Episode 250, Total Reward: 5.252341337674671
# Episode 251, Total Reward: 2.7457287192908897
# Episode 252, Total Reward: 5.252341337674671
# Episode 253, Total Reward: 5.252341337674671
# Episode 254, Total Reward: 3.2008008568710107
# Episode 255, Total Reward: 3.2008008568710107
# Episode 256, Total Reward: 5.252341337674671
# Episode 257, Total Reward: 5.252341337674671
# Episode 258, Total Reward: 3.8658701407267984
# Episode 259, Total Reward: 5.252341337674671
# Episode 260, Total Reward: 3.1733275222729724
# Episode 261, Total Reward: 5.252341337674671
# Episode 262, Total Reward: 3.614515486140286
# Episode 263, Total Reward: 5.252341337674671
# Episode 264, Total Reward: 5.252341337674671
# Episode 265, Total Reward: 3.2008008568710107
# Episode 266, Total Reward: 5.252341337674671
# Episode 267, Total Reward: 5.252341337674671
# Episode 268, Total Reward: 5.252341337674671
# Episode 269, Total Reward: 5.252341337674671
# Episode 270, Total Reward: 5.252341337674671
# Episode 271, Total Reward: 5.252341337674671
# Episode 272, Total Reward: 5.252341337674671
# Episode 273, Total Reward: 4.39053428942428
# Episode 274, Total Reward: 1.6783008318409662
# Episode 275, Total Reward: 3.6056985896556197
# Episode 276, Total Reward: 5.252341337674671
# Episode 277, Total Reward: 5.252341337674671
# Episode 278, Total Reward: 5.252341337674671
# Episode 279, Total Reward: 1.6490335940127547
# Episode 280, Total Reward: 5.252341337674671
# Episode 281, Total Reward: 5.252341337674671
# Episode 282, Total Reward: 5.252341337674671
# Episode 283, Total Reward: 5.252341337674671
# Episode 284, Total Reward: 5.252341337674671
# Episode 285, Total Reward: 5.252341337674671
# Episode 286, Total Reward: 5.252341337674671
# Episode 287, Total Reward: 3.2008008568710107
# Episode 288, Total Reward: 5.252341337674671
# Episode 289, Total Reward: 3.620424933595786
# Episode 290, Total Reward: 5.252341337674671
# Episode 291, Total Reward: 5.252341337674671
# Episode 292, Total Reward: 5.252341337674671
# Episode 293, Total Reward: 5.252341337674671
# Episode 294, Total Reward: 5.252341337674671
# Episode 295, Total Reward: 5.252341337674671
# Episode 296, Total Reward: 5.252341337674671
# Episode 297, Total Reward: 5.252341337674671
# Episode 298, Total Reward: 5.252341337674671
# Episode 299, Total Reward: 5.252341337674671
# Episode 300, Total Reward: 5.252341337674671
# Episode 301, Total Reward: 5.252341337674671
# Episode 302, Total Reward: 5.252341337674671
# Episode 303, Total Reward: 3.1929726097260858
# Episode 304, Total Reward: 5.252341337674671
# Episode 305, Total Reward: 3.567956378261502
# Episode 306, Total Reward: 5.252341337674671
# Episode 307, Total Reward: 5.252341337674671
# Episode 308, Total Reward: 5.252341337674671
# Episode 309, Total Reward: 5.252341337674671
# Episode 310, Total Reward: 5.252341337674671
# Episode 311, Total Reward: 5.252341337674671
# Episode 312, Total Reward: 5.252341337674671
# Episode 313, Total Reward: 2.3099060620142438
# Episode 314, Total Reward: 5.252341337674671
# Episode 315, Total Reward: 5.252341337674671
# Episode 316, Total Reward: 5.252341337674671
# Episode 317, Total Reward: 5.252341337674671
# Episode 318, Total Reward: 5.252341337674671
# Episode 319, Total Reward: 5.252341337674671
# Episode 320, Total Reward: 5.252341337674671
# Episode 321, Total Reward: 5.252341337674671
# Episode 322, Total Reward: 5.252341337674671
# Episode 323, Total Reward: 5.252341337674671
# Episode 324, Total Reward: 3.620424933595786
# Episode 325, Total Reward: 5.252341337674671
# Episode 326, Total Reward: 4.39053428942428
# Episode 327, Total Reward: 5.252341337674671
# Episode 328, Total Reward: 5.252341337674671
# Episode 329, Total Reward: 5.252341337674671
# Episode 330, Total Reward: 4.39053428942428
# Episode 331, Total Reward: 5.252341337674671
# Episode 332, Total Reward: 5.252341337674671
# Episode 333, Total Reward: 5.252341337674671
# Episode 334, Total Reward: 5.252341337674671
# Episode 335, Total Reward: 3.6056985896556197
# Episode 336, Total Reward: 5.252341337674671
# Episode 337, Total Reward: 5.252341337674671
# Episode 338, Total Reward: 5.252341337674671
# Episode 339, Total Reward: 5.252341337674671
# Episode 340, Total Reward: 5.252341337674671
# Episode 341, Total Reward: 3.614515486140286
# Episode 342, Total Reward: 3.8658701407267984
# Episode 343, Total Reward: 2.8078055081599893
# Episode 344, Total Reward: 2.1061484047385886
# Episode 345, Total Reward: 5.252341337674671
# Episode 346, Total Reward: 2.7457287192908897
# Episode 347, Total Reward: 5.252341337674671
# Episode 348, Total Reward: 5.252341337674671
# Episode 349, Total Reward: 5.252341337674671
# Episode 350, Total Reward: 3.1733275222729724
# Episode 351, Total Reward: 5.252341337674671
# Episode 352, Total Reward: 5.252341337674671
# Episode 353, Total Reward: 5.252341337674671
# Episode 354, Total Reward: 5.252341337674671
# Episode 355, Total Reward: 5.252341337674671
# Episode 356, Total Reward: 5.252341337674671
# Episode 357, Total Reward: 5.252341337674671
# Episode 358, Total Reward: 5.252341337674671
# Episode 359, Total Reward: 5.252341337674671
# Episode 360, Total Reward: 5.252341337674671
# Episode 361, Total Reward: 5.252341337674671
# Episode 362, Total Reward: 5.252341337674671
# Episode 363, Total Reward: 3.1929726097260858
# Episode 364, Total Reward: 5.252341337674671
# Episode 365, Total Reward: 5.252341337674671
# Episode 366, Total Reward: 5.252341337674671
# Episode 367, Total Reward: 5.252341337674671
# Episode 368, Total Reward: 5.252341337674671
# Episode 369, Total Reward: 5.252341337674671
# Episode 370, Total Reward: 5.252341337674671
# Episode 371, Total Reward: 5.252341337674671
# Episode 372, Total Reward: 5.252341337674671
# Episode 373, Total Reward: 5.252341337674671
# Episode 374, Total Reward: 3.6056985896556197
# Episode 375, Total Reward: 5.252341337674671
# Episode 376, Total Reward: 5.252341337674671
# Episode 377, Total Reward: 5.252341337674671
# Episode 378, Total Reward: 5.252341337674671
# Episode 379, Total Reward: 5.252341337674671
# Episode 380, Total Reward: 5.252341337674671
# Episode 381, Total Reward: 5.252341337674671
# Episode 382, Total Reward: 5.252341337674671
# Episode 383, Total Reward: 3.549153165065487
# Episode 384, Total Reward: 5.252341337674671
# Episode 385, Total Reward: 5.252341337674671
# Episode 386, Total Reward: 4.5041269723132915
# Episode 387, Total Reward: 5.252341337674671
# Episode 388, Total Reward: 5.252341337674671
# Episode 389, Total Reward: 5.252341337674671
# Episode 390, Total Reward: 5.252341337674671
# Episode 391, Total Reward: 5.252341337674671
# Episode 392, Total Reward: 5.252341337674671
# Episode 393, Total Reward: 5.252341337674671
# Episode 394, Total Reward: 5.252341337674671
# Episode 395, Total Reward: 5.252341337674671
# Episode 396, Total Reward: 5.252341337674671
# Episode 397, Total Reward: 5.252341337674671
# Episode 398, Total Reward: 4.420481582672803
# Episode 399, Total Reward: 5.252341337674671
# Episode 400, Total Reward: 5.252341337674671
# Episode 401, Total Reward: 5.252341337674671
# Episode 402, Total Reward: 5.252341337674671
# Episode 403, Total Reward: 3.6054532192336453
# Episode 404, Total Reward: 4.39053428942428
# Episode 405, Total Reward: 5.252341337674671
# Episode 406, Total Reward: 5.252341337674671
# Episode 407, Total Reward: 3.549153165065487
# Episode 408, Total Reward: 5.252341337674671
# Episode 409, Total Reward: 5.252341337674671
# Episode 410, Total Reward: 3.751584208672874
# Episode 411, Total Reward: 5.252341337674671
# Episode 412, Total Reward: 5.252341337674671
# Episode 413, Total Reward: 5.252341337674671
# Episode 414, Total Reward: 5.252341337674671
# Episode 415, Total Reward: 5.252341337674671
# Episode 416, Total Reward: 3.4458062205945144
# Episode 417, Total Reward: 3.1733275222729724
# Episode 418, Total Reward: 3.6054532192336453
# Episode 419, Total Reward: 5.252341337674671
# Episode 420, Total Reward: 5.252341337674671
# Episode 421, Total Reward: 5.252341337674671
# Episode 422, Total Reward: 5.252341337674671
# Episode 423, Total Reward: 5.252341337674671
# Episode 424, Total Reward: 5.252341337674671
# Episode 425, Total Reward: 5.252341337674671
# Episode 426, Total Reward: 5.252341337674671
# Episode 427, Total Reward: 5.252341337674671
# Episode 428, Total Reward: 5.252341337674671
# Episode 429, Total Reward: 5.252341337674671
# Episode 430, Total Reward: 5.252341337674671
# Episode 431, Total Reward: 5.252341337674671
# Episode 432, Total Reward: 5.252341337674671
# Episode 433, Total Reward: 5.252341337674671
# Episode 434, Total Reward: 5.252341337674671
# Episode 435, Total Reward: 5.252341337674671
# Episode 436, Total Reward: 3.498007248773058
# Episode 437, Total Reward: 5.252341337674671
# Episode 438, Total Reward: 5.252341337674671
# Episode 439, Total Reward: 5.252341337674671
# Episode 440, Total Reward: 5.252341337674671
# Episode 441, Total Reward: 5.252341337674671
# Episode 442, Total Reward: 5.252341337674671
# Episode 443, Total Reward: 5.252341337674671
# Episode 444, Total Reward: 5.252341337674671
# Episode 445, Total Reward: 5.252341337674671
# Episode 446, Total Reward: 3.6056985896556197
# Episode 447, Total Reward: 5.252341337674671
# Episode 448, Total Reward: 5.252341337674671
# Episode 449, Total Reward: 5.252341337674671
# Episode 450, Total Reward: 3.4458062205945144
# Episode 451, Total Reward: 2.6119353716991074
# Episode 452, Total Reward: 5.252341337674671
# Episode 453, Total Reward: 5.252341337674671
# Episode 454, Total Reward: 5.252341337674671
# Episode 455, Total Reward: 2.8137192301186382
# Episode 456, Total Reward: 5.252341337674671
# Episode 457, Total Reward: 5.252341337674671
# Episode 458, Total Reward: 5.252341337674671
# Episode 459, Total Reward: 5.252341337674671
# Episode 460, Total Reward: 5.252341337674671
# Episode 461, Total Reward: 5.252341337674671
# Episode 462, Total Reward: 5.252341337674671
# Episode 463, Total Reward: 3.4458062205945144
# Episode 464, Total Reward: 5.252341337674671
# Episode 465, Total Reward: 5.252341337674671
# Episode 466, Total Reward: 5.252341337674671
# Episode 467, Total Reward: 5.252341337674671
# Episode 468, Total Reward: 5.252341337674671
# Episode 469, Total Reward: 5.252341337674671
# Episode 470, Total Reward: 5.252341337674671
# Episode 471, Total Reward: 5.252341337674671
# Episode 472, Total Reward: 4.4231178431426255
# Episode 473, Total Reward: 5.252341337674671
# Episode 474, Total Reward: 5.252341337674671
# Episode 475, Total Reward: 5.252341337674671
# Episode 476, Total Reward: 3.1733275222729724
# Episode 477, Total Reward: 5.252341337674671
# Episode 478, Total Reward: 5.252341337674671
# Episode 479, Total Reward: 3.498007248773058
# Episode 480, Total Reward: 3.4935117467201136
# Episode 481, Total Reward: 3.1929726097260858
# Episode 482, Total Reward: 5.252341337674671
# Episode 483, Total Reward: 5.252341337674671
# Episode 484, Total Reward: 3.751584208672874
# Episode 485, Total Reward: 5.252341337674671
# Episode 486, Total Reward: 2.7457287192908897
# Episode 487, Total Reward: 5.252341337674671
# Episode 488, Total Reward: 5.252341337674671
# Episode 489, Total Reward: 5.252341337674671
# Episode 490, Total Reward: 5.252341337674671
# Episode 491, Total Reward: 5.252341337674671
# Episode 492, Total Reward: 5.252341337674671
# Episode 493, Total Reward: 5.252341337674671
# Episode 494, Total Reward: 5.252341337674671
# Episode 495, Total Reward: 5.252341337674671
# Episode 496, Total Reward: 5.252341337674671
# Episode 497, Total Reward: 5.252341337674671
# Episode 498, Total Reward: 5.252341337674671
# Episode 499, Total Reward: 5.252341337674671
# Episode 500, Total Reward: 2.953200747620646
# Episode 501, Total Reward: 5.252341337674671
# Episode 502, Total Reward: 5.252341337674671
# Episode 503, Total Reward: 5.252341337674671
# Episode 504, Total Reward: 5.252341337674671
# Episode 505, Total Reward: 5.252341337674671
# Episode 506, Total Reward: 5.252341337674671
# Episode 507, Total Reward: 5.252341337674671
# Episode 508, Total Reward: 5.252341337674671
# Episode 509, Total Reward: 3.498007248773058
# Episode 510, Total Reward: 5.252341337674671
# Episode 511, Total Reward: 5.252341337674671
# Episode 512, Total Reward: 3.620424933595786
# Episode 513, Total Reward: 5.252341337674671
# Episode 514, Total Reward: 5.252341337674671
# Episode 515, Total Reward: 5.252341337674671
# Episode 516, Total Reward: 5.252341337674671
# Episode 517, Total Reward: 5.252341337674671
# Episode 518, Total Reward: 3.549153165065487
# Episode 519, Total Reward: 5.252341337674671
# Episode 520, Total Reward: 5.252341337674671
# Episode 521, Total Reward: 5.252341337674671
# Episode 522, Total Reward: 5.252341337674671
# Episode 523, Total Reward: 5.252341337674671
# Episode 524, Total Reward: 3.6056985896556197
# Episode 525, Total Reward: 5.252341337674671
# Episode 526, Total Reward: 5.252341337674671
# Episode 527, Total Reward: 5.252341337674671
# Episode 528, Total Reward: 5.252341337674671
# Episode 529, Total Reward: 5.252341337674671
# Episode 530, Total Reward: 5.252341337674671
# Episode 531, Total Reward: 5.252341337674671
# Episode 532, Total Reward: 2.7457287192908897
# Episode 533, Total Reward: 5.252341337674671
# Episode 534, Total Reward: 3.614515486140286
# Episode 535, Total Reward: 5.252341337674671
# Episode 536, Total Reward: 5.252341337674671
# Episode 537, Total Reward: 5.252341337674671
# Episode 538, Total Reward: 5.252341337674671
# Episode 539, Total Reward: 5.252341337674671
# Episode 540, Total Reward: 5.252341337674671
# Episode 541, Total Reward: 5.252341337674671
# Episode 542, Total Reward: 5.252341337674671
# Episode 543, Total Reward: 5.252341337674671
# Episode 544, Total Reward: 5.252341337674671
# Episode 545, Total Reward: 5.252341337674671
# Episode 546, Total Reward: 5.252341337674671
# Episode 547, Total Reward: 5.252341337674671
# Episode 548, Total Reward: 5.252341337674671
# Episode 549, Total Reward: 2.921418701247633
# Episode 550, Total Reward: 5.252341337674671
# Episode 551, Total Reward: 2.7457287192908897
# Episode 552, Total Reward: 3.4458062205945144
# Episode 553, Total Reward: 5.252341337674671
# Episode 554, Total Reward: 5.252341337674671
# Episode 555, Total Reward: 5.252341337674671
# Episode 556, Total Reward: 5.252341337674671
# Episode 557, Total Reward: 5.252341337674671
# Episode 558, Total Reward: 5.252341337674671
# Episode 559, Total Reward: 5.252341337674671
# Episode 560, Total Reward: 5.252341337674671
# Episode 561, Total Reward: 5.252341337674671
# Episode 562, Total Reward: 5.252341337674671
# Episode 563, Total Reward: 3.107430140147727
# Episode 564, Total Reward: 5.252341337674671
# Episode 565, Total Reward: 5.252341337674671
# Episode 566, Total Reward: 3.107430140147727
# Episode 567, Total Reward: 5.252341337674671
# Episode 568, Total Reward: 5.252341337674671
# Episode 569, Total Reward: 5.252341337674671
# Episode 570, Total Reward: 5.252341337674671
# Episode 571, Total Reward: 3.1733275222729724
# Episode 572, Total Reward: 5.252341337674671
# Episode 573, Total Reward: 5.252341337674671
# Episode 574, Total Reward: 5.252341337674671
# Episode 575, Total Reward: 5.252341337674671
# Episode 576, Total Reward: 5.252341337674671
# Episode 577, Total Reward: 4.5041269723132915
# Episode 578, Total Reward: 5.252341337674671
# Episode 579, Total Reward: 5.252341337674671
# Episode 580, Total Reward: 3.4458062205945144
# Episode 581, Total Reward: 5.252341337674671
# Episode 582, Total Reward: 5.252341337674671
# Episode 583, Total Reward: 5.252341337674671
# Episode 584, Total Reward: 5.252341337674671
# Episode 585, Total Reward: 5.252341337674671
# Episode 586, Total Reward: 2.7457287192908897
# Episode 587, Total Reward: 3.107430140147727
# Episode 588, Total Reward: 5.252341337674671
# Episode 589, Total Reward: 3.107430140147727
# Episode 590, Total Reward: 5.252341337674671
# Episode 591, Total Reward: 5.252341337674671
# Episode 592, Total Reward: 5.252341337674671
# Episode 593, Total Reward: 5.252341337674671
# Episode 594, Total Reward: 5.252341337674671
# Episode 595, Total Reward: 5.252341337674671
# Episode 596, Total Reward: 5.252341337674671
# Episode 597, Total Reward: 5.252341337674671
# Episode 598, Total Reward: 5.252341337674671
# Episode 599, Total Reward: 5.252341337674671
# Episode 600, Total Reward: 5.252341337674671
# Episode 601, Total Reward: 5.252341337674671
# Episode 602, Total Reward: 5.252341337674671
# Episode 603, Total Reward: 5.252341337674671
# Episode 604, Total Reward: 5.252341337674671
# Episode 605, Total Reward: 5.252341337674671
# Episode 606, Total Reward: 5.252341337674671
# Episode 607, Total Reward: 5.252341337674671
# Episode 608, Total Reward: 5.252341337674671
# Episode 609, Total Reward: 5.252341337674671
# Episode 610, Total Reward: 5.252341337674671
# Episode 611, Total Reward: 2.8137192301186382
# Episode 612, Total Reward: 5.252341337674671
# Episode 613, Total Reward: 3.4935117467201136
# Episode 614, Total Reward: 5.252341337674671
# Episode 615, Total Reward: 3.620424933595786
# Episode 616, Total Reward: 5.252341337674671
# Episode 617, Total Reward: 5.252341337674671
# Episode 618, Total Reward: 5.252341337674671
# Episode 619, Total Reward: 5.252341337674671
# Episode 620, Total Reward: 5.252341337674671
# Episode 621, Total Reward: 5.252341337674671
# Episode 622, Total Reward: 5.252341337674671
# Episode 623, Total Reward: 5.252341337674671
# Episode 624, Total Reward: 5.252341337674671
# Episode 625, Total Reward: 3.751584208672874
# Episode 626, Total Reward: 3.6056985896556197
# Episode 627, Total Reward: 5.252341337674671
# Episode 628, Total Reward: 5.252341337674671
# Episode 629, Total Reward: 3.1929726097260858
# Episode 630, Total Reward: 4.420481582672803
# Episode 631, Total Reward: 5.252341337674671
# Episode 632, Total Reward: 5.252341337674671
# Episode 633, Total Reward: 5.252341337674671
# Episode 634, Total Reward: 5.252341337674671
# Episode 635, Total Reward: 5.252341337674671
# Episode 636, Total Reward: 5.252341337674671
# Episode 637, Total Reward: 5.252341337674671
# Episode 638, Total Reward: 5.252341337674671
# Episode 639, Total Reward: 5.252341337674671
# Episode 640, Total Reward: 5.252341337674671
# Episode 641, Total Reward: 5.252341337674671
# Episode 642, Total Reward: 5.252341337674671
# Episode 643, Total Reward: 5.252341337674671
# Episode 644, Total Reward: 5.252341337674671
# Episode 645, Total Reward: 5.252341337674671
# Episode 646, Total Reward: 5.252341337674671
# Episode 647, Total Reward: 3.498007248773058
# Episode 648, Total Reward: 5.252341337674671
# Episode 649, Total Reward: 5.252341337674671
# Episode 650, Total Reward: 5.252341337674671
# Episode 651, Total Reward: 5.252341337674671
# Episode 652, Total Reward: 3.614515486140286
# Episode 653, Total Reward: 3.6056985896556197
# Episode 654, Total Reward: 5.252341337674671
# Episode 655, Total Reward: 2.7457287192908897
# Episode 656, Total Reward: 5.252341337674671
# Episode 657, Total Reward: 5.252341337674671
# Episode 658, Total Reward: 5.252341337674671
# Episode 659, Total Reward: 5.252341337674671
# Episode 660, Total Reward: 5.252341337674671
# Episode 661, Total Reward: 5.252341337674671
# Episode 662, Total Reward: 5.252341337674671
# Episode 663, Total Reward: 5.252341337674671
# Episode 664, Total Reward: 5.252341337674671
# Episode 665, Total Reward: 5.252341337674671
# Episode 666, Total Reward: 5.252341337674671
# Episode 667, Total Reward: 5.252341337674671
# Episode 668, Total Reward: 5.252341337674671
# Episode 669, Total Reward: 3.608930286842325
# Episode 670, Total Reward: 5.252341337674671
# Episode 671, Total Reward: 5.252341337674671
# Episode 672, Total Reward: 5.252341337674671
# Episode 673, Total Reward: 5.252341337674671
# Episode 674, Total Reward: 4.39053428942428
# Episode 675, Total Reward: 5.252341337674671
# Episode 676, Total Reward: 5.252341337674671
# Episode 677, Total Reward: 3.4458062205945144
# Episode 678, Total Reward: 5.252341337674671
# Episode 679, Total Reward: 5.252341337674671
# Episode 680, Total Reward: 5.252341337674671
# Episode 681, Total Reward: 5.252341337674671
# Episode 682, Total Reward: 5.252341337674671
# Episode 683, Total Reward: 5.252341337674671
# Episode 684, Total Reward: 5.252341337674671
# Episode 685, Total Reward: 5.252341337674671
# Episode 686, Total Reward: 5.252341337674671
# Episode 687, Total Reward: 5.252341337674671
# Episode 688, Total Reward: 5.252341337674671
# Episode 689, Total Reward: 3.608930286842325
# Episode 690, Total Reward: 2.8137192301186382
# Episode 691, Total Reward: 5.252341337674671
# Episode 692, Total Reward: 5.252341337674671
# Episode 693, Total Reward: 5.252341337674671
# Episode 694, Total Reward: 5.252341337674671
# Episode 695, Total Reward: 5.252341337674671
# Episode 696, Total Reward: 3.2008008568710107
# Episode 697, Total Reward: 5.252341337674671
# Episode 698, Total Reward: 5.252341337674671
# Episode 699, Total Reward: 5.252341337674671
# Episode 700, Total Reward: 5.252341337674671
# Episode 701, Total Reward: 3.2008008568710107
# Episode 702, Total Reward: 5.252341337674671
# Episode 703, Total Reward: 5.252341337674671
# Episode 704, Total Reward: 5.252341337674671
# Episode 705, Total Reward: 5.252341337674671
# Episode 706, Total Reward: 5.252341337674671
# Episode 707, Total Reward: 5.252341337674671
# Episode 708, Total Reward: 5.252341337674671
# Episode 709, Total Reward: 5.252341337674671
# Episode 710, Total Reward: 5.252341337674671
# Episode 711, Total Reward: 5.252341337674671
# Episode 712, Total Reward: 3.8658701407267984
# Episode 713, Total Reward: 5.252341337674671
# Episode 714, Total Reward: 5.252341337674671
# Episode 715, Total Reward: 5.252341337674671
# Episode 716, Total Reward: 5.252341337674671
# Episode 717, Total Reward: 5.252341337674671
# Episode 718, Total Reward: 5.252341337674671
# Episode 719, Total Reward: 5.252341337674671
# Episode 720, Total Reward: 3.4935117467201136
# Episode 721, Total Reward: 5.252341337674671
# Episode 722, Total Reward: 5.252341337674671
# Episode 723, Total Reward: 5.252341337674671
# Episode 724, Total Reward: 5.252341337674671
# Episode 725, Total Reward: 5.252341337674671
# Episode 726, Total Reward: 5.252341337674671
# Episode 727, Total Reward: 5.252341337674671
# Episode 728, Total Reward: 5.252341337674671
# Episode 729, Total Reward: 3.052602731224651
# Episode 730, Total Reward: 3.4458062205945144
# Episode 731, Total Reward: 5.252341337674671
# Episode 732, Total Reward: 5.252341337674671
# Episode 733, Total Reward: 5.252341337674671
# Episode 734, Total Reward: 5.252341337674671
# Episode 735, Total Reward: 5.252341337674671
# Episode 736, Total Reward: 5.252341337674671
# Episode 737, Total Reward: 5.252341337674671
# Episode 738, Total Reward: 5.252341337674671
# Episode 739, Total Reward: 3.1929726097260858
# Episode 740, Total Reward: 5.252341337674671
# Episode 741, Total Reward: 5.252341337674671
# Episode 742, Total Reward: 5.252341337674671
# Episode 743, Total Reward: 5.252341337674671
# Episode 744, Total Reward: 5.252341337674671
# Episode 745, Total Reward: 5.252341337674671
# Episode 746, Total Reward: 3.8658701407267984
# Episode 747, Total Reward: 5.252341337674671
# Episode 748, Total Reward: 5.252341337674671
# Episode 749, Total Reward: 5.252341337674671
# Episode 750, Total Reward: 5.252341337674671
# Episode 751, Total Reward: 2.120670170468423
# Episode 752, Total Reward: 5.252341337674671
# Episode 753, Total Reward: 5.252341337674671
# Episode 754, Total Reward: 3.1929726097260858
# Episode 755, Total Reward: 5.252341337674671
# Episode 756, Total Reward: 5.252341337674671
# Episode 757, Total Reward: 5.252341337674671
# Episode 758, Total Reward: 5.252341337674671
# Episode 759, Total Reward: 5.252341337674671
# Episode 760, Total Reward: 5.252341337674671
# Episode 761, Total Reward: 5.252341337674671
# Episode 762, Total Reward: 5.252341337674671
# Episode 763, Total Reward: 5.252341337674671
# Episode 764, Total Reward: 3.107430140147727
# Episode 765, Total Reward: 5.252341337674671
# Episode 766, Total Reward: 5.252341337674671
# Episode 767, Total Reward: 5.252341337674671
# Episode 768, Total Reward: 2.7457287192908897
# Episode 769, Total Reward: 5.252341337674671
# Episode 770, Total Reward: 5.252341337674671
# Episode 771, Total Reward: 5.252341337674671
# Episode 772, Total Reward: 3.608930286842325
# Episode 773, Total Reward: 3.620424933595786
# Episode 774, Total Reward: 5.252341337674671
# Episode 775, Total Reward: 5.252341337674671
# Episode 776, Total Reward: 5.252341337674671
# Episode 777, Total Reward: 5.252341337674671
# Episode 778, Total Reward: 5.252341337674671
# Episode 779, Total Reward: 3.8658701407267984
# Episode 780, Total Reward: 5.252341337674671
# Episode 781, Total Reward: 5.252341337674671
# Episode 782, Total Reward: 5.252341337674671
# Episode 783, Total Reward: 5.252341337674671
# Episode 784, Total Reward: 5.252341337674671
# Episode 785, Total Reward: 4.4231178431426255
# Episode 786, Total Reward: 5.252341337674671
# Episode 787, Total Reward: 5.252341337674671
# Episode 788, Total Reward: 5.252341337674671
# Episode 789, Total Reward: 5.252341337674671
# Episode 790, Total Reward: 5.252341337674671
# Episode 791, Total Reward: 4.39053428942428
# Episode 792, Total Reward: 5.252341337674671
# Episode 793, Total Reward: 5.252341337674671
# Episode 794, Total Reward: 5.252341337674671
# Episode 795, Total Reward: 5.252341337674671
# Episode 796, Total Reward: 5.252341337674671
# Episode 797, Total Reward: 5.252341337674671
# Episode 798, Total Reward: 2.8137192301186382
# Episode 799, Total Reward: 5.252341337674671
# Episode 800, Total Reward: 5.252341337674671
# Episode 801, Total Reward: 5.252341337674671
# Episode 802, Total Reward: 5.252341337674671
# Episode 803, Total Reward: 5.252341337674671
# Episode 804, Total Reward: 3.620424933595786
# Episode 805, Total Reward: 5.252341337674671
# Episode 806, Total Reward: 5.252341337674671
# Episode 807, Total Reward: 5.252341337674671
# Episode 808, Total Reward: 5.252341337674671
# Episode 809, Total Reward: 5.252341337674671
# Episode 810, Total Reward: 5.252341337674671
# Episode 811, Total Reward: 5.252341337674671
# Episode 812, Total Reward: 3.4935117467201136
# Episode 813, Total Reward: 5.252341337674671
# Episode 814, Total Reward: 2.8137192301186382
# Episode 815, Total Reward: 5.252341337674671
# Episode 816, Total Reward: 5.252341337674671
# Episode 817, Total Reward: 5.252341337674671
# Episode 818, Total Reward: 5.252341337674671
# Episode 819, Total Reward: 5.252341337674671
# Episode 820, Total Reward: 5.252341337674671
# Episode 821, Total Reward: 5.252341337674671
# Episode 822, Total Reward: 5.252341337674671
# Episode 823, Total Reward: 5.252341337674671
# Episode 824, Total Reward: 5.252341337674671
# Episode 825, Total Reward: 5.252341337674671
# Episode 826, Total Reward: 5.252341337674671
# Episode 827, Total Reward: 3.620424933595786
# Episode 828, Total Reward: 5.252341337674671
# Episode 829, Total Reward: 5.252341337674671
# Episode 830, Total Reward: 5.252341337674671
# Episode 831, Total Reward: 3.1929726097260858
# Episode 832, Total Reward: 4.420481582672803
# Episode 833, Total Reward: 5.252341337674671
# Episode 834, Total Reward: 5.252341337674671
# Episode 835, Total Reward: 5.252341337674671
# Episode 836, Total Reward: 5.252341337674671
# Episode 837, Total Reward: 5.252341337674671
# Episode 838, Total Reward: 5.252341337674671
# Episode 839, Total Reward: 5.252341337674671
# Episode 840, Total Reward: 3.608930286842325
# Episode 841, Total Reward: 5.252341337674671
# Episode 842, Total Reward: 5.252341337674671
# Episode 843, Total Reward: 5.252341337674671
# Episode 844, Total Reward: 3.107430140147727
# Episode 845, Total Reward: 5.252341337674671
# Episode 846, Total Reward: 5.252341337674671
# Episode 847, Total Reward: 5.252341337674671
# Episode 848, Total Reward: 5.252341337674671
# Episode 849, Total Reward: 5.252341337674671
# Episode 850, Total Reward: 5.252341337674671
# Episode 851, Total Reward: 5.252341337674671
# Episode 852, Total Reward: 5.252341337674671
# Episode 853, Total Reward: 5.252341337674671
# Episode 854, Total Reward: 5.252341337674671
# Episode 855, Total Reward: 5.252341337674671
# Episode 856, Total Reward: 5.252341337674671
# Episode 857, Total Reward: 4.4231178431426255
# Episode 858, Total Reward: 5.252341337674671
# Episode 859, Total Reward: 5.252341337674671
# Episode 860, Total Reward: 3.8658701407267984
# Episode 861, Total Reward: 2.3140204391717676
# Episode 862, Total Reward: 5.252341337674671
# Episode 863, Total Reward: 5.252341337674671
# Episode 864, Total Reward: 5.252341337674671
# Episode 865, Total Reward: 5.252341337674671
# Episode 866, Total Reward: 3.562370242439126
# Episode 867, Total Reward: 5.252341337674671
# Episode 868, Total Reward: 5.252341337674671
# Episode 869, Total Reward: 5.252341337674671
# Episode 870, Total Reward: 5.252341337674671
# Episode 871, Total Reward: 5.252341337674671
# Episode 872, Total Reward: 5.252341337674671
# Episode 873, Total Reward: 5.252341337674671
# Episode 874, Total Reward: 5.252341337674671
# Episode 875, Total Reward: 5.252341337674671
# Episode 876, Total Reward: 1.6783051063441154
# Episode 877, Total Reward: 5.252341337674671
# Episode 878, Total Reward: 5.252341337674671
# Episode 879, Total Reward: 5.252341337674671
# Episode 880, Total Reward: 5.252341337674671
# Episode 881, Total Reward: 5.252341337674671
# Episode 882, Total Reward: 5.252341337674671
# Episode 883, Total Reward: 5.252341337674671
# Episode 884, Total Reward: 5.252341337674671
# Episode 885, Total Reward: 3.562370242439126
# Episode 886, Total Reward: 4.420481582672803
# Episode 887, Total Reward: 3.8658701407267984
# Episode 888, Total Reward: 5.252341337674671
# Episode 889, Total Reward: 5.252341337674671
# Episode 890, Total Reward: 3.107430140147727
# Episode 891, Total Reward: 5.252341337674671
# Episode 892, Total Reward: 5.252341337674671
# Episode 893, Total Reward: 3.608930286842325
# Episode 894, Total Reward: 5.252341337674671
# Episode 895, Total Reward: 5.252341337674671
# Episode 896, Total Reward: 5.252341337674671
# Episode 897, Total Reward: 5.252341337674671
# Episode 898, Total Reward: 5.252341337674671
# Episode 899, Total Reward: 5.252341337674671
# Episode 900, Total Reward: 5.252341337674671
# Episode 901, Total Reward: 3.562370242439126
# Episode 902, Total Reward: 3.614515486140286
# Episode 903, Total Reward: 5.252341337674671
# Episode 904, Total Reward: 5.252341337674671
# Episode 905, Total Reward: 5.252341337674671
# Episode 906, Total Reward: 5.252341337674671
# Episode 907, Total Reward: 5.252341337674671
# Episode 908, Total Reward: 5.252341337674671
# Episode 909, Total Reward: 4.4231178431426255
# Episode 910, Total Reward: 2.8078055081599893
# Episode 911, Total Reward: 5.252341337674671
# Episode 912, Total Reward: 5.252341337674671
# Episode 913, Total Reward: 5.252341337674671
# Episode 914, Total Reward: 3.608930286842325
# Episode 915, Total Reward: 5.252341337674671
# Episode 916, Total Reward: 5.252341337674671
# Episode 917, Total Reward: 5.252341337674671
# Episode 918, Total Reward: 5.252341337674671
# Episode 919, Total Reward: 5.252341337674671
# Episode 920, Total Reward: 5.252341337674671
# Episode 921, Total Reward: 2.8137192301186382
# Episode 922, Total Reward: 4.4231178431426255
# Episode 923, Total Reward: 3.567956378261502
# Episode 924, Total Reward: 5.252341337674671
# Episode 925, Total Reward: 2.7457287192908897
# Episode 926, Total Reward: 5.252341337674671
# Episode 927, Total Reward: 5.252341337674671
# Episode 928, Total Reward: 3.614515486140286
# Episode 929, Total Reward: 5.252341337674671
# Episode 930, Total Reward: 5.252341337674671
# Episode 931, Total Reward: 5.252341337674671
# Episode 932, Total Reward: 3.549153165065487
# Episode 933, Total Reward: 3.107430140147727
# Episode 934, Total Reward: 5.252341337674671
# Episode 935, Total Reward: 4.39053428942428
# Episode 936, Total Reward: 5.252341337674671
# Episode 937, Total Reward: 5.252341337674671
# Episode 938, Total Reward: 5.252341337674671
# Episode 939, Total Reward: 5.252341337674671
# Episode 940, Total Reward: 5.252341337674671
# Episode 941, Total Reward: 5.252341337674671
# Episode 942, Total Reward: 5.252341337674671
# Episode 943, Total Reward: 5.252341337674671
# Episode 944, Total Reward: 5.252341337674671
# Episode 945, Total Reward: 3.620424933595786
# Episode 946, Total Reward: 3.751584208672874
# Episode 947, Total Reward: 3.751584208672874
# Episode 948, Total Reward: 5.252341337674671
# Episode 949, Total Reward: 2.9733121106132625
# Episode 950, Total Reward: 5.252341337674671
# Episode 951, Total Reward: 4.39053428942428
# Episode 952, Total Reward: 5.252341337674671
# Episode 953, Total Reward: 5.252341337674671
# Episode 954, Total Reward: 5.252341337674671
# Episode 955, Total Reward: 5.252341337674671
# Episode 956, Total Reward: 5.252341337674671
# Episode 957, Total Reward: 5.252341337674671
# Episode 958, Total Reward: 5.252341337674671
# Episode 959, Total Reward: 5.252341337674671
# Episode 960, Total Reward: 5.252341337674671
# Episode 961, Total Reward: 5.252341337674671
# Episode 962, Total Reward: 5.252341337674671
# Episode 963, Total Reward: 5.252341337674671
# Episode 964, Total Reward: 5.252341337674671
# Episode 965, Total Reward: 5.252341337674671
# Episode 966, Total Reward: 5.252341337674671
# Episode 967, Total Reward: 5.252341337674671
# Episode 968, Total Reward: 5.252341337674671
# Episode 969, Total Reward: 5.252341337674671
# Episode 970, Total Reward: 5.252341337674671
# Episode 971, Total Reward: 5.252341337674671
# Episode 972, Total Reward: 5.252341337674671
# Episode 973, Total Reward: 5.252341337674671
# Episode 974, Total Reward: 5.252341337674671
# Episode 975, Total Reward: 5.252341337674671
# Episode 976, Total Reward: 5.252341337674671
# Episode 977, Total Reward: 5.252341337674671
# Episode 978, Total Reward: 5.252341337674671
# Episode 979, Total Reward: 3.614515486140286
# Episode 980, Total Reward: 5.252341337674671
# Episode 981, Total Reward: 5.252341337674671
# Episode 982, Total Reward: 5.252341337674671
# Episode 983, Total Reward: 5.252341337674671
# Episode 984, Total Reward: 5.252341337674671
# Episode 985, Total Reward: 5.252341337674671
# Episode 986, Total Reward: 5.252341337674671
# Episode 987, Total Reward: 3.8658701407267984
# Episode 988, Total Reward: 3.567956378261502
# Episode 989, Total Reward: 4.4231178431426255
# Episode 990, Total Reward: 5.252341337674671
# Episode 991, Total Reward: 5.252341337674671
# Episode 992, Total Reward: 5.252341337674671
# Episode 993, Total Reward: 2.8137192301186382
# Episode 994, Total Reward: 5.252341337674671
# Episode 995, Total Reward: 5.252341337674671
# Episode 996, Total Reward: 5.252341337674671
# Episode 997, Total Reward: 5.252341337674671
# Episode 998, Total Reward: 5.252341337674671
# Episode 999, Total Reward: 5.252341337674671
# Episode 1000, Total Reward: 5.252341337674671
# Episode 1001, Total Reward: 5.252341337674671
# Episode 1002, Total Reward: 5.252341337674671
# Episode 1003, Total Reward: 5.252341337674671
# Episode 1004, Total Reward: 5.252341337674671
# Episode 1005, Total Reward: 5.252341337674671
# Episode 1006, Total Reward: 5.252341337674671
# Episode 1007, Total Reward: 4.420481582672803
# Episode 1008, Total Reward: 5.252341337674671
# Episode 1009, Total Reward: 5.252341337674671
# Episode 1010, Total Reward: 5.252341337674671
# Episode 1011, Total Reward: 5.252341337674671
# Episode 1012, Total Reward: 5.252341337674671
# Episode 1013, Total Reward: 5.252341337674671
# Episode 1014, Total Reward: 5.252341337674671
# Episode 1015, Total Reward: 2.8078055081599893
# Episode 1016, Total Reward: 5.252341337674671
# Episode 1017, Total Reward: 5.252341337674671
# Episode 1018, Total Reward: 5.252341337674671
# Episode 1019, Total Reward: 3.614515486140286
# Episode 1020, Total Reward: 3.751584208672874
# Episode 1021, Total Reward: 5.252341337674671
# Episode 1022, Total Reward: 5.252341337674671
# Episode 1023, Total Reward: 5.252341337674671
# Episode 1024, Total Reward: 5.252341337674671
# Episode 1025, Total Reward: 5.252341337674671
# Episode 1026, Total Reward: 5.252341337674671
# Episode 1027, Total Reward: 3.562370242439126
# Episode 1028, Total Reward: 5.252341337674671
# Episode 1029, Total Reward: 2.498752175428339
# Episode 1030, Total Reward: 5.252341337674671
# Episode 1031, Total Reward: 3.608930286842325
# Episode 1032, Total Reward: 5.252341337674671
# Episode 1033, Total Reward: 5.252341337674671
# Episode 1034, Total Reward: 5.252341337674671
# Episode 1035, Total Reward: 5.252341337674671
# Episode 1036, Total Reward: 5.252341337674671
# Episode 1037, Total Reward: 3.107430140147727
# Episode 1038, Total Reward: 5.252341337674671
# Episode 1039, Total Reward: 5.252341337674671
# Episode 1040, Total Reward: 3.4935117467201136
# Episode 1041, Total Reward: 5.252341337674671
# Episode 1042, Total Reward: 5.252341337674671
# Episode 1043, Total Reward: 5.252341337674671
# Episode 1044, Total Reward: 5.252341337674671
# Episode 1045, Total Reward: 3.8658701407267984
# Episode 1046, Total Reward: 5.252341337674671
# Episode 1047, Total Reward: 5.252341337674671
# Episode 1048, Total Reward: 5.252341337674671
# Episode 1049, Total Reward: 5.252341337674671
# Episode 1050, Total Reward: 5.252341337674671
# Episode 1051, Total Reward: 5.252341337674671
# Episode 1052, Total Reward: 5.252341337674671
# Episode 1053, Total Reward: 5.252341337674671
# Episode 1054, Total Reward: 5.252341337674671
# Episode 1055, Total Reward: 3.107430140147727
# Episode 1056, Total Reward: 5.252341337674671
# Episode 1057, Total Reward: 5.252341337674671
# Episode 1058, Total Reward: 5.252341337674671
# Episode 1059, Total Reward: 5.252341337674671
# Episode 1060, Total Reward: 5.252341337674671
# Episode 1061, Total Reward: 5.252341337674671
# Episode 1062, Total Reward: 5.252341337674671
# Episode 1063, Total Reward: 5.252341337674671
# ...
# Episode 1949, Total Reward: 5.252341337674671
# Episode 1950, Total Reward: 5.252341337674671
# Episode 1951, Total Reward: 5.252341337674671
# Episode 1952, Total Reward: 4.5041269723132915
# Episode 1953, Total Reward: 5.252341337674671
# Episode 1954, Total Reward: 5.252341337674671
# Episode 1955, Total Reward: 5.252341337674671
# Episode 1956, Total Reward: 5.252341337674671
# Episode 1957, Total Reward: 5.252341337674671
# Episode 1958, Total Reward: 5.252341337674671
# Episode 1959, Total Reward: 4.39053428942428
# Episode 1960, Total Reward: 5.252341337674671
# Episode 1961, Total Reward: 5.252341337674671
# Episode 1962, Total Reward: 5.252341337674671
# Episode 1963, Total Reward: 5.252341337674671
# Episode 1964, Total Reward: 3.608930286842325
# Episode 1965, Total Reward: 5.252341337674671
# Episode 1966, Total Reward: 5.252341337674671
# Episode 1967, Total Reward: 5.252341337674671
# Episode 1968, Total Reward: 3.2008008568710107
# Episode 1969, Total Reward: 5.252341337674671
# Episode 1970, Total Reward: 5.252341337674671
# Episode 1971, Total Reward: 5.252341337674671
# Episode 1972, Total Reward: 5.252341337674671
# Episode 1973, Total Reward: 5.252341337674671
# Episode 1974, Total Reward: 5.252341337674671
# Episode 1975, Total Reward: 5.252341337674671
# Episode 1976, Total Reward: 5.252341337674671
# Episode 1977, Total Reward: 5.252341337674671
# Episode 1978, Total Reward: 5.252341337674671
# Episode 1979, Total Reward: 5.252341337674671
# Episode 1980, Total Reward: 2.8078055081599893
# Episode 1981, Total Reward: 3.549153165065487
# Episode 1982, Total Reward: 3.6056985896556197
# Episode 1983, Total Reward: 5.252341337674671
# Episode 1984, Total Reward: 5.252341337674671
# Episode 1985, Total Reward: 5.252341337674671
# Episode 1986, Total Reward: 5.252341337674671
# Episode 1987, Total Reward: 3.751584208672874
# Episode 1988, Total Reward: 5.252341337674671
# Episode 1989, Total Reward: 5.252341337674671
# Episode 1990, Total Reward: 4.5041269723132915
# Episode 1991, Total Reward: 5.252341337674671
# Episode 1992, Total Reward: 3.614515486140286
# Episode 1993, Total Reward: 5.252341337674671
# Episode 1994, Total Reward: 5.252341337674671
# Episode 1995, Total Reward: 5.252341337674671
# Episode 1996, Total Reward: 5.252341337674671
# Episode 1997, Total Reward: 5.252341337674671
# Episode 1998, Total Reward: 5.252341337674671
# Episode 1999, Total Reward: 5.252341337674671
# Episode 2000, Total Reward: 5.252341337674671
# Episode 2001, Total Reward: 5.252341337674671
# Episode 2002, Total Reward: 5.252341337674671
# Episode 2003, Total Reward: 5.252341337674671
# Episode 2004, Total Reward: 5.252341337674671
# Episode 2005, Total Reward: 5.252341337674671
# Episode 2006, Total Reward: 5.252341337674671
# Episode 2007, Total Reward: 4.5041269723132915
# Episode 2008, Total Reward: 5.252341337674671
# Episode 2009, Total Reward: 5.252341337674671
# Episode 2010, Total Reward: 4.4231178431426255
# Episode 2011, Total Reward: 5.252341337674671
# Episode 2012, Total Reward: 5.252341337674671
# Episode 2013, Total Reward: 5.252341337674671
# Episode 2014, Total Reward: 5.252341337674671
# Episode 2015, Total Reward: 2.8137192301186382
# Episode 2016, Total Reward: 5.252341337674671
# Episode 2017, Total Reward: 5.252341337674671
# Episode 2018, Total Reward: 5.252341337674671
# Episode 2019, Total Reward: 5.252341337674671
# Episode 2020, Total Reward: 5.252341337674671
# Episode 2021, Total Reward: 5.252341337674671
# Episode 2022, Total Reward: 3.2008008568710107
# Episode 2023, Total Reward: 5.252341337674671
# Episode 2024, Total Reward: 5.252341337674671
# Episode 2025, Total Reward: 5.252341337674671
# Episode 2026, Total Reward: 5.252341337674671
# Episode 2027, Total Reward: 5.252341337674671
# Episode 2028, Total Reward: 5.252341337674671
# Episode 2029, Total Reward: 5.252341337674671
# Episode 2030, Total Reward: 5.252341337674671
# Episode 2031, Total Reward: 5.252341337674671
# Episode 2032, Total Reward: 5.252341337674671
# Episode 2033, Total Reward: 5.252341337674671
# Episode 2034, Total Reward: 2.8078055081599893
# Episode 2035, Total Reward: 3.620424933595786
# Episode 2036, Total Reward: 5.252341337674671
# Episode 2037, Total Reward: 5.252341337674671
# Episode 2038, Total Reward: 5.252341337674671
# Episode 2039, Total Reward: 5.252341337674671
# Episode 2040, Total Reward: 5.252341337674671
# Episode 2041, Total Reward: 5.252341337674671
# Episode 2042, Total Reward: 5.252341337674671
# Episode 2043, Total Reward: 5.252341337674671
# Episode 2044, Total Reward: 5.252341337674671
# Episode 2045, Total Reward: 5.252341337674671
# Episode 2046, Total Reward: 5.252341337674671
# Episode 2047, Total Reward: 5.252341337674671
# Episode 2048, Total Reward: 3.6056985896556197
# Episode 2049, Total Reward: 5.252341337674671
# Episode 2050, Total Reward: 5.252341337674671
# Episode 2051, Total Reward: 3.608930286842325
# Episode 2052, Total Reward: 3.107430140147727
# Episode 2053, Total Reward: 5.252341337674671
# Episode 2054, Total Reward: 5.252341337674671
# Episode 2055, Total Reward: 5.252341337674671
# Episode 2056, Total Reward: 5.252341337674671
# Episode 2057, Total Reward: 5.252341337674671
# Episode 2058, Total Reward: 5.252341337674671
# Episode 2059, Total Reward: 5.252341337674671
# Episode 2060, Total Reward: 5.252341337674671
# Episode 2061, Total Reward: 5.252341337674671
# Episode 2062, Total Reward: 5.252341337674671
# Episode 2063, Total Reward: 3.8658701407267984
# Episode 2064, Total Reward: 5.252341337674671
# Episode 2065, Total Reward: 3.4935117467201136
# Episode 2066, Total Reward: 5.252341337674671
# Episode 2067, Total Reward: 5.252341337674671
# Episode 2068, Total Reward: 5.252341337674671
# Episode 2069, Total Reward: 5.252341337674671
# Episode 2070, Total Reward: 2.8137192301186382
# Episode 2071, Total Reward: 5.252341337674671
# Episode 2072, Total Reward: 3.1733275222729724
# Episode 2073, Total Reward: 5.252341337674671
# Episode 2074, Total Reward: 5.252341337674671
# Episode 2075, Total Reward: 3.608930286842325
# Episode 2076, Total Reward: 5.252341337674671
# Episode 2077, Total Reward: 5.252341337674671
# Episode 2078, Total Reward: 3.4458062205945144
# Episode 2079, Total Reward: 3.567956378261502
# Episode 2080, Total Reward: 5.252341337674671
# Episode 2081, Total Reward: 5.252341337674671
# Episode 2082, Total Reward: 5.252341337674671
# Episode 2083, Total Reward: 5.252341337674671
# Episode 2084, Total Reward: 5.252341337674671
# Episode 2085, Total Reward: 5.252341337674671
# Episode 2086, Total Reward: 5.252341337674671
# Episode 2087, Total Reward: 5.252341337674671
# Episode 2088, Total Reward: 5.252341337674671
# Episode 2089, Total Reward: 5.252341337674671
# Episode 2090, Total Reward: 5.252341337674671
# Episode 2091, Total Reward: 5.252341337674671
# Episode 2092, Total Reward: 5.252341337674671
# Episode 2093, Total Reward: 5.252341337674671
# Episode 2094, Total Reward: 5.252341337674671
# Episode 2095, Total Reward: 5.252341337674671
# Episode 2096, Total Reward: 5.252341337674671
# Episode 2097, Total Reward: 5.252341337674671
# Episode 2098, Total Reward: 5.252341337674671
# Episode 2099, Total Reward: 5.252341337674671
# Episode 2100, Total Reward: 5.252341337674671
# Episode 2101, Total Reward: 5.252341337674671
# Episode 2102, Total Reward: 5.252341337674671
# Episode 2103, Total Reward: 4.420481582672803
# Episode 2104, Total Reward: 5.252341337674671
# Episode 2105, Total Reward: 5.252341337674671
# Episode 2106, Total Reward: 5.252341337674671
# Episode 2107, Total Reward: 5.252341337674671
# Episode 2108, Total Reward: 3.2008008568710107
# Episode 2109, Total Reward: 5.252341337674671
# Episode 2110, Total Reward: 5.252341337674671
# Episode 2111, Total Reward: 5.252341337674671
# Episode 2112, Total Reward: 5.252341337674671
# Episode 2113, Total Reward: 2.8137192301186382
# Episode 2114, Total Reward: 5.252341337674671
# Episode 2115, Total Reward: 5.252341337674671
# Episode 2116, Total Reward: 5.252341337674671
# Episode 2117, Total Reward: 3.751584208672874
# Episode 2118, Total Reward: 5.252341337674671
# Episode 2119, Total Reward: 5.252341337674671
# Episode 2120, Total Reward: 5.252341337674671
# Episode 2121, Total Reward: 5.252341337674671
# Episode 2122, Total Reward: 2.7457287192908897
# Episode 2123, Total Reward: 5.252341337674671
# Episode 2124, Total Reward: 3.6056985896556197
# Episode 2125, Total Reward: 5.252341337674671
# Episode 2126, Total Reward: 5.252341337674671
# Episode 2127, Total Reward: 5.252341337674671
# Episode 2128, Total Reward: 5.252341337674671
# Episode 2129, Total Reward: 5.252341337674671
# Episode 2130, Total Reward: 5.252341337674671
# Episode 2131, Total Reward: 5.252341337674671
# Episode 2132, Total Reward: 5.252341337674671
# Episode 2133, Total Reward: 5.252341337674671
# Episode 2134, Total Reward: 5.252341337674671
# Episode 2135, Total Reward: 5.252341337674671
# Episode 2136, Total Reward: 5.252341337674671
# Episode 2137, Total Reward: 5.252341337674671
# Episode 2138, Total Reward: 5.252341337674671
# Episode 2139, Total Reward: 3.751584208672874
# Episode 2140, Total Reward: 3.4935117467201136
# Episode 2141, Total Reward: 5.252341337674671
# Episode 2142, Total Reward: 5.252341337674671
# Episode 2143, Total Reward: 5.252341337674671
# Episode 2144, Total Reward: 2.8137192301186382
# Episode 2145, Total Reward: 5.252341337674671
# Episode 2146, Total Reward: 5.252341337674671
# Episode 2147, Total Reward: 5.252341337674671
# Episode 2148, Total Reward: 5.252341337674671
# Episode 2149, Total Reward: 5.252341337674671
# Episode 2150, Total Reward: 5.252341337674671
# Episode 2151, Total Reward: 3.608930286842325
# Episode 2152, Total Reward: 3.4458062205945144
# Episode 2153, Total Reward: 5.252341337674671
# Episode 2154, Total Reward: 5.252341337674671
# Episode 2155, Total Reward: 5.252341337674671
# Episode 2156, Total Reward: 5.252341337674671
# Episode 2157, Total Reward: 5.252341337674671
# Episode 2158, Total Reward: 5.252341337674671
# Episode 2159, Total Reward: 5.252341337674671
# Episode 2160, Total Reward: 4.420481582672803
# Episode 2161, Total Reward: 5.252341337674671
# Episode 2162, Total Reward: 5.252341337674671
# Episode 2163, Total Reward: 3.8658701407267984
# Episode 2164, Total Reward: 3.498007248773058
# Episode 2165, Total Reward: 5.252341337674671
# Episode 2166, Total Reward: 5.252341337674671
# Episode 2167, Total Reward: 5.252341337674671
# Episode 2168, Total Reward: 5.252341337674671
# Episode 2169, Total Reward: 5.252341337674671
# Episode 2170, Total Reward: 2.7457287192908897
# Episode 2171, Total Reward: 5.252341337674671
# Episode 2172, Total Reward: 5.252341337674671
# Episode 2173, Total Reward: 3.498007248773058
# Episode 2174, Total Reward: 4.4231178431426255
# Episode 2175, Total Reward: 4.4231178431426255
# Episode 2176, Total Reward: 5.252341337674671
# Episode 2177, Total Reward: 3.608930286842325
# Episode 2178, Total Reward: 3.1929726097260858
# Episode 2179, Total Reward: 5.252341337674671
# Episode 2180, Total Reward: 5.252341337674671
# Episode 2181, Total Reward: 5.252341337674671
# Episode 2182, Total Reward: 5.252341337674671
# Episode 2183, Total Reward: 3.107430140147727
# Episode 2184, Total Reward: 2.7457287192908897
# Episode 2185, Total Reward: 2.7457287192908897
# Episode 2186, Total Reward: 5.252341337674671
# Episode 2187, Total Reward: 5.252341337674671
# Episode 2188, Total Reward: 5.252341337674671
# Episode 2189, Total Reward: 5.252341337674671
# Episode 2190, Total Reward: 5.252341337674671
# Episode 2191, Total Reward: 5.252341337674671
# Episode 2192, Total Reward: 5.252341337674671
# Episode 2193, Total Reward: 5.252341337674671
# Episode 2194, Total Reward: 5.252341337674671
# Episode 2195, Total Reward: 5.252341337674671
# Episode 2196, Total Reward: 2.200006931732945
# Episode 2197, Total Reward: 5.252341337674671
# Episode 2198, Total Reward: 5.252341337674671
# Episode 2199, Total Reward: 5.252341337674671
# Episode 2200, Total Reward: 5.252341337674671
# Training complete
# [0.12465168944240164, 0.1298669272586458, 0.06866208652806845, 0.1387697233770837, 0.15356520274566443, 0.12385468196637124, 0.08193128359000408, 0.11649333628063165, 0.1338992075268166, 0.11994284229745777, 0.16746057731108144, 0.10156226618296234, 0.12126047667751573, 0.10490509407199157, 0.06537985924335593, 0.1701710221061604, 0.24210012210012208, 0.07588117545882513, 0.14029126126653765, 0.057655777520864517, 0.10493447473959565, 0.16991867241631053, 0.19738324771824786, 0.13735269157692448, 0.18230577611868404, 0.15412432035207316, 0.10459397689369708, 0.10921160893633315, 0.21247908500686305, 0.24210012210012208, 0.1980314660267386, 0.19738324771824786, 0.21247908500686305, 0.15859423223886265, 0.18390227512060284, 0.10236055565499358, 0.2100901766284342, 0.08692040569888519, 0.12360943911044305, 0.14341527910673832, 0.2100901766284342, 0.1673469555147383, 0.1973299989695462, 0.14495364000327948, 0.24210012210012208, 0.18677007781741253, 0.24210012210012208, 0.18677007781741253, 0.21191605352836096, 0.1980314660267386, 0.18230577611868404, 0.13731746539492817, 0.1980314660267386, 0.24210012210012208, 0.2118656081694299, 0.19738324771824786, 0.24210012210012208, 0.1973299989695462, 0.2118656081694299, 0.24210012210012208, 0.24210012210012208, 0.14428931471715198, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.16681583119415475, 0.21247908500686305, 0.24210012210012208, 0.18233689011065737, 0.24210012210012208, 0.16751447509147707, 0.24210012210012208, 0.24210012210012208, 0.1973299989695462, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.21191605352836096, 0.24210012210012208, 0.2118656081694299, 0.1828342622451202, 0.16823781897154302, 0.16681583119415475, 0.18230577611868404, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.2100901766284342, 0.19738324771824786, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.18230577611868404, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.1973299989695462, 0.24210012210012208, 0.18233689011065737, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.1828342622451202, 0.24210012210012208, 0.18233689011065737, 0.24210012210012208, 0.24210012210012208, 0.18677007781741253, 0.19738324771824786, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.18233689011065737, 0.24210012210012208, 0.24210012210012208, 0.1828342622451202, 0.1980314660267386, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.1973299989695462, 0.24210012210012208, 0.24210012210012208, 0.18230577611868404, 0.24210012210012208, 0.24210012210012208, 0.2100901766284342, 0.24210012210012208, 0.19750005556155012, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.2118656081694299, 0.24210012210012208, 0.19738324771824786, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.18233689011065737, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.2118656081694299, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.1973299989695462, 0.24210012210012208, 0.1828342622451202, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.18233689011065737, 0.24210012210012208, 0.24210012210012208, 0.24210012210012208, 0.2421001221001 ...
# Listing all servers and deployed microservices:
# Server s1 (10.0.0.1): Deployed Microservices -> ['m1', 'm2', 'm3', 'm11', 'm22', 'm32']
# Server s2 (10.0.0.2): Deployed Microservices -> []
# Server s3 (10.0.0.3): Deployed Microservices -> []
# Server s4 (10.0.0.4): Deployed Microservices -> []
# Server s5 (10.0.0.5): Deployed Microservices -> []

# %%
#ٍSucessful Deployments
for microservice in deployment_env.microservices:
    deployment_env.current_microservice = microservice
    action_index = random.randint(0, len(deployment_env.graph.nodes) - 1)
    print(f"Deploying {microservice.service_id} to server at index {action_index}")
    action_result = deployment_env.execute_action(action_index)
    print(f"Deployment result: {action_result}")

print("\nTesting special scenarios:")

# Simulate a failed deployment due to insufficient resources
print("\nDeploying a microservice with requirements exceeding any server's capacity...")
big_microservice = Microservice("big_service", "Big Data", 500, 600, 5000, 10)
deployment_env.current_microservice = big_microservice
action_index = random.randint(0, len(deployment_env.graph.nodes) - 1)
action_result = deployment_env.execute_action(action_index)
print(f"Deployment result for big service to server at index {action_index}: {action_result}")

# Simulate an invalid action
print("\nAttempting to deploy to an invalid server index...")
invalid_index = len(deployment_env.graph.nodes)  # Index out of range
deployment_env.current_microservice = microservice1  # Re-using microservice1 for this test
action_result = deployment_env.execute_action(invalid_index)
print(f"Deployment result for invalid index: {action_result}")

# Test deploying a microservice to a server that does not meet its requirements
print("\nDeploying microservice with specific requirements not met by the chosen server...")
specific_microservice = Microservice("specific_service", "Specific Task", 200, 300, 1500, 5)  # Requirements not met by at least one server
deployment_env.current_microservice = specific_microservice
action_index = 0 
action_result = deployment_env.execute_action(action_index)
print(f"Deployment result for specific service to server at index {action_index} (requirements not met): {action_result}")


network_graph.visualize()

list_servers_and_microservices(network_graph)
plot_resource_utilization_for_all_servers_pct(network_graph)
